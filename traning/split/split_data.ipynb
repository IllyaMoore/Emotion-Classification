# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("C:\Emotion Classification\data\\full_dataset\goemotions_1.csv", sep=',')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\illya\AppData\Local\Temp\ipykernel_23436\3787783419.py:1: SyntaxWarning: invalid escape sequence '\E'
#   data = pd.read_csv("C:\Emotion Classification\data\\full_dataset\goemotions_1.csv", sep=',')

# %%
data.describe()
# Out:
#         created_utc      rater_id    admiration     amusement         anger  \
# count  7.000000e+04  70000.000000  70000.000000  70000.000000  70000.000000
# mean   1.547656e+09     37.526686      0.080671      0.044014      0.036986
# std    7.700606e+05     23.039283      0.272332      0.205128      0.188728
# min    1.546301e+09      0.000000      0.000000      0.000000      0.000000
# 25%    1.546990e+09     19.000000      0.000000      0.000000      0.000000
# 50%    1.547660e+09     37.000000      0.000000      0.000000      0.000000
# 75%    1.548312e+09     57.000000      0.000000      0.000000      0.000000
# max    1.548979e+09     81.000000      1.000000      1.000000      1.000000
#
#           annoyance      approval        caring     confusion     curiosity  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean       0.063471      0.084686      0.028400      0.035300      0.046671
# ...

# %%
train = data.sample(frac=0.8, random_state=42)
test = data.drop(train.index)

# %%
data.shape, train.shape, test.shape
# Out:
# ((70000, 37), (56000, 37), (14000, 37))

# %%
train.to_csv("C:\Emotion Classification\\traning\\traningData\\train.csv", index=False)
test.to_csv("C:\Emotion Classification\\traning\\traningData\\test.csv", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\illya\AppData\Local\Temp\ipykernel_23436\1478478044.py:1: SyntaxWarning: invalid escape sequence '\E'
#   train.to_csv("C:\Emotion Classification\\traning\\traningData\\train.csv", index=False)
# C:\Users\illya\AppData\Local\Temp\ipykernel_23436\1478478044.py:2: SyntaxWarning: invalid escape sequence '\E'
#   test.to_csv("C:\Emotion Classification\\traning\\traningData\\test.csv", index=False)
